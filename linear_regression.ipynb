# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Salary.csv')

# %%
data.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
X = data[['YearsExperience']]
y = data[['Salary']]

# %%
X.shape
# Out:
# (35, 1)

# %%
plt.scatter(X, y)
plt.xlabel('Year of experience')
plt.ylabel('Total salary')
# Out:
# Text(0, 0.5, 'Total salary')

# %%
from sklearn.model_selection import train_test_split
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 40)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
x_test  = scaler.transform(x_test)
plt.scatter(X_train, y_train)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_test= regression.predict(x_test)

# %%
plt.scatter(x_test, y_pred_test)

# %%
regression.coef_
# Out:
# array([[27835.86248867]])

# %%
regression.intercept_
# Out:
# array([79793.33333333])

# %%
from sklearn.metrics import accuracy_score,mean_absolute_error, mean_squared_error
import numpy as np
print(f'Mean squared error {mean_squared_error(y_test, y_pred_test)}')
print(f'Mean Absoulte error {mean_absolute_error(y_test, y_pred_test)}')
print(f'RMSE {np.sqrt(mean_squared_error(y_test, y_pred_test))}')
# Out:
# Mean squared error 38394871.304732315
# Mean Absoulte error 5477.465793033178
# RMSE 6196.359520293534

# %%
#### new input

scaled_experience = scaler.transform([[5]])
scaled_experience
# Out:
# array([[5.]])

# %%
regression.predict(scaled_experience)
# Out:
# array([[218972.64577666]])

# %%
### Pickle file
import pickle
with open('scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

# %%
with open('regression.pkl', 'wb') as file:
    pickle.dump(regression, file)
